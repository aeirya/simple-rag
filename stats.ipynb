# %%
import wiki

theme_stats = dict()
for theme, items in wiki.pages.items():
    theme_stats[theme] = len(items)

theme_stats
# Out:
# {'language': 13,
#  'language_family': 8,
#  'linguistics': 9,
#  'country': 10,
#  'capital_city': 10,
#  'food': 10,
#  'irrelevant_general': 20}

# %%
theme_stats
# Out:
# {'language': 13,
#  'language_family': 8,
#  'linguistics': 9,
#  'country': 10,
#  'capital_city': 10,
#  'food': 10,
#  'irrelevant_general': 20}
